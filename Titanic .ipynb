# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data_Cleaning

# %%
df=pd.read_csv("D:/Data/Intership/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Fill Null values in Age

# %%
Average_age=df['Age'].mean()
Average_age
# Out:
# 29.69911764705882

# %%
Avg_Age=Average_age.round()
Avg_Age
# Out:
# 30.0

# %%
df["Age"]=df["Age"].replace(np.nan,Avg_Age)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Cabin"].mode()
# Out:
# 0        B96 B98
# 1    C23 C25 C27
# 2             G6
# Name: Cabin, dtype: object

# %% [markdown]
# # Drop Cabin Column

# %%
df.drop(columns=["Cabin"],inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
fill_null=df["Embarked"].mode().iloc[0]
fill_null
# Out:
# 'S'

# %%
df["Embarked"]=df["Embarked"].replace(np.nan,fill_null)

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Ticket_Number"]=df["Ticket"].str.extract('(\d+(?=\D*$))')

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass
# 790          791         0       3  \
# 872          873         0       1
# 318          319         1       1
# 794          795         0       3
# 412          413         1       1
# 846          847         0       3
# 263          264         0       1
# 731          732         0       3
# 382          383         0       3
# 18            19         0       3
#
#                                                   Name     Sex   Age  SibSp
# 790                           Keane, Mr. Andrew "Andy"    male  30.0      0  \
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 318                           Wick, Miss. Mary Natalie  female  31.0      0
# 794                              Dantcheff, Mr. Ristiu    male  25.0      0
# 412                             Minahan, Miss. Daisy E  female  33.0      1
# 846                           Sage, Mr. Douglas Bullen    male  30.0      8
# ...

# %%
df.drop(columns='Ticket',inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Sex"]=df["Sex"].str.title()

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    Male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Survived"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df["Pclass"].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df["Parch"].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
df["SibSp"].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
df["Sex"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.dtypes
# Out:
# PassengerId        int64
# Survived           int64
# Pclass             int64
# Name              object
# Sex               object
# Age              float64
# SibSp              int64
# Parch              int64
# Fare             float64
# Embarked          object
# Ticket_Number     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Fare             0
# Embarked         0
# Ticket_Number    4
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex
# 179          180         0       3              Leonard, Mr. Lionel  Male  \
# 271          272         1       3     Tornquist, Mr. William Henry  Male
# 302          303         0       3  Johnson, Mr. William Cahoone Jr  Male
# 597          598         0       3              Johnson, Mr. Alfred  Male
#
#       Age  SibSp  Parch  Fare Embarked Ticket_Number
# 179  36.0      0      0   0.0        S           NaN
# 271  25.0      0      0   0.0        S           NaN
# 302  19.0      0      0   0.0        S           NaN
# 597  49.0      0      0   0.0        S           NaN

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Fare             0
# Embarked         0
# Ticket_Number    4
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    Male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Fare             0
# Embarked         0
# Ticket_Number    4
# dtype: int64

# %%
df["Ticket_Number"]=df["Ticket_Number"].replace(np.nan,'Unpaid')

# %%
df[df["Ticket_Number"]=='Unpaid']
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex
# 179          180         0       3              Leonard, Mr. Lionel  Male  \
# 271          272         1       3     Tornquist, Mr. William Henry  Male
# 302          303         0       3  Johnson, Mr. William Cahoone Jr  Male
# 597          598         0       3              Johnson, Mr. Alfred  Male
#
#       Age  SibSp  Parch  Fare Embarked Ticket_Number
# 179  36.0      0      0   0.0        S        Unpaid
# 271  25.0      0      0   0.0        S        Unpaid
# 302  19.0      0      0   0.0        S        Unpaid
# 597  49.0      0      0   0.0        S        Unpaid

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Fare             0
# Embarked         0
# Ticket_Number    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PassengerId    891 non-null    int64
#  1   Survived       891 non-null    int64
#  2   Pclass         891 non-null    int64
#  3   Name           891 non-null    object
#  4   Sex            891 non-null    object
#  5   Age            891 non-null    float64
#  6   SibSp          891 non-null    int64
#  7   Parch          891 non-null    int64
#  8   Fare           891 non-null    float64
#  9   Embarked       891 non-null    object
#  10  Ticket_Number  891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp
# count   891.000000  891.000000  891.000000  891.000000  891.000000  \
# mean    446.000000    0.383838    2.308642   29.758889    0.523008
# std     257.353842    0.486592    0.836071   13.002570    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   30.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Handel Outliers

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    Male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Q25 = df['Age'].quantile(0.25)
Q75 = df['Age'].quantile(0.75)
IQR = Q75 - Q25
MIN_Value = Q25 - (1.5*IQR)
MAX_value = Q75 + (1.5*IQR)

# %%
MAX_value,MIN_Value
# Out:
# (54.5, 2.5)

# %%
df.loc[(df['Age']<=MIN_Value) | (df['Age']>=MAX_value)]
# Out:
#      PassengerId  Survived  Pclass
# 7              8         0       3  \
# 11            12         1       1
# 15            16         1       2
# 16            17         0       3
# 33            34         0       2
# ..           ...       ...     ...
# 827          828         1       2
# 829          830         1       1
# 831          832         1       2
# 851          852         0       3
# 879          880         1       1
#
#                                               Name     Sex    Age  SibSp
# 7                   Palsson, Master. Gosta Leonard    Male   2.00      3  \
# 11                        Bonnell, Miss. Elizabeth  Female  58.00      0
# 15                Hewlett, Mrs. (Mary D Kingcome)   Female  55.00      0
# 16                            Rice, Master. Eugene    Male   2.00      4
# 33                           Wheadon, Mr. Edward H    Male  66.00      0
# ..                                             ...     ...    ...    ...
# ...

# %%
new_df=df.loc[(df['Age']>=MIN_Value) & (df['Age']<=MAX_value)]

# %%
new_df.loc[(new_df['Age']<=MIN_Value) | (new_df['Age']>=MAX_value)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Fare, Embarked, Ticket_Number]
# Index: []

# %%
new_df=new_df.loc[new_df['Age']<=55]

# %%
new_df[new_df['Age']>55]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Fare, Embarked, Ticket_Number]
# Index: []

# %%
new_df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    Male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Q25_F = df['Fare'].quantile(0.25)
Q75_F = df['Fare'].quantile(0.75)
IQR_F = Q75_F -Q25_F

# %%
MIN_V_F = Q25_F - (1.5*IQR_F)
MAX_V_F = Q75_F + (1.5*IQR_F)
MAX_V_F,MIN_V_F
# Out:
# (65.6344, -26.724)

# %%
df.loc[(df['Fare']< MIN_V_F) | (df['Fare']>MAX_V_F)]
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 27            28         0       1
# 31            32         1       1
# 34            35         0       1
# 52            53         1       1
# ..           ...       ...     ...
# 846          847         0       3
# 849          850         1       1
# 856          857         1       1
# 863          864         0       3
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1  \
# 27                      Fortune, Mr. Charles Alexander    Male  19.0      3
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  Female  30.0      1
# 34                             Meyer, Mr. Edgar Joseph    Male  28.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  Female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
new_df = df.loc[(df['Fare']>MIN_V_F) & (df['Fare']<MAX_V_F)]
new_df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch
# 0                         Braund, Mr. Owen Harris    Male  22.0      1      0  \
# 2                          Heikkinen, Miss. Laina  Female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1      0
# 4                        Allen, Mr. William Henry    Male  35.0      0      0
# 5                                Moran, Mr. James    Male  30.0      0      0
# ...

# %%
new_df.loc[(new_df['Fare']< MIN_V_F) | (new_df['Fare']>MAX_V_F)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Fare, Embarked, Ticket_Number]
# Index: []

# %%
new_df[new_df['Fare']>=65.6344]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Fare, Embarked, Ticket_Number]
# Index: []

# %%
new_df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch
# 0                         Braund, Mr. Owen Harris    Male  22.0      1      0  \
# 2                          Heikkinen, Miss. Laina  Female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1      0
# 4                        Allen, Mr. William Henry    Male  35.0      0      0
# 5                                Moran, Mr. James    Male  30.0      0      0
# ...

# %% [markdown]
# # summary statistics

# %%
new_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp
# count   745.000000  745.000000  745.000000  745.000000  745.000000  \
# mean    447.279195    0.346309    2.511409   27.811074    0.453691
# std     260.578430    0.476113    0.712931   11.002110    0.913351
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     215.000000    0.000000    2.000000   22.000000    0.000000
# 50%     448.000000    0.000000    3.000000   30.000000    0.000000
# 75%     674.000000    1.000000    3.000000   32.000000    1.000000
# max     891.000000    1.000000    3.000000   55.000000    5.000000
#
#             Parch        Fare
# count  745.000000  745.000000
# mean     0.351678   17.621095
# std      0.798066   13.533052
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   12.650000
# 75%      0.000000   26.000000
# max      6.000000   65.000000

# %%
new_df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch
# 0                         Braund, Mr. Owen Harris    Male  22.0      1      0  \
# 2                          Heikkinen, Miss. Laina  Female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1      0
# 4                        Allen, Mr. William Henry    Male  35.0      0      0
# 5                                Moran, Mr. James    Male  30.0      0      0
# ...

# %%
new_df['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
new_df['Survived'].mode()
# Out:
# 0    0
# Name: Survived, dtype: int64

# %%
new_df['Survived'].value_counts()
# Out:
# Survived
# 0    487
# 1    258
# Name: count, dtype: int64

# %%
new_df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
new_df['Pclass'].mode()
# Out:
# 0    3
# Name: Pclass, dtype: int64

# %%
new_df['Pclass'].value_counts()
# Out:
# Pclass
# 3    477
# 2    172
# 1     96
# Name: count, dtype: int64

# %%
new_df['Sex'].value_counts()
# Out:
# Sex
# Male      504
# Female    241
# Name: count, dtype: int64

# %%
new_df['Age'].max()
# Out:
# 55.0

# %%
new_df['Age'].min()
# Out:
# 0.42

# %%
new_df['Age'].median()
# Out:
# 30.0

# %%
new_df['Age'].mean()
# Out:
# 27.811073825503357

# %%
new_df['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5], dtype=int64)

# %%
new_df['SibSp'].value_counts()
# Out:
# SibSp
# 0    528
# 1    160
# 2     21
# 4     18
# 3     13
# 5      5
# Name: count, dtype: int64

# %%
new_df['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
new_df['Parch'].value_counts()
# Out:
# Parch
# 0    581
# 1     96
# 2     54
# 5      5
# 3      5
# 4      3
# 6      1
# Name: count, dtype: int64

# %%
new_df['Fare'].max()
# Out:
# 65.0

# %%
new_df['Fare'].min()
# Out:
# 0.0

# %%
new_df['Fare'].median()
# Out:
# 12.65

# %%
new_df['Fare'].mean()
# Out:
# 17.621095436241614
